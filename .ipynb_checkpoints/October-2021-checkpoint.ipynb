# %%
import pandas as pd
import matplotlib.pyplot as plt
import six
import numpy as np

data = {'No' : ['1','2','3','4','5','6','7','8','9'], 
        'Registered Date':['10/06/2021','10/06/2021','10/06/2021','10/03/2021','10/03/2021','10/03/2021','10/03/2021','10/03/2021', '10/03/2021'],
        'Username':['Mohamad Askar', 'Noviar Gozali', 'Irene Elysia Gunawan', 'Alvin Oslan', 'Alexander Natanael Sinuraya', 'Devy Martin', 'Cindy Lusiany', 'Francis Anderson', 'Nindya Meranti Iskandar'],
        'Affiliation' : ['Alumni','Alumni','Alumni','Alumni','Alumni','Alumni','Alumni','Alumni','Alumni'], 
        'Email' : ['mohamad_askar2011@yahoo.com','aries.noviar.g@gmail.com','irenelysia@yahoo.com','alvinoslan@gmail.com','alexander.sinuraya','aspal_bahe@yahoo.com','clusiany7@gmail.com','kojongianz@gmail.com','nindyami13@gmail.com']}
df3 = pd.DataFrame(data)

def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')

    mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)

    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in  six.iteritems(mpl_table._cells):
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax

render_mpl_table(df3, header_columns=0, col_width=5.0)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import six
import numpy as np

data = {'No' : ['1','2','3','4','5','6','7','8','9'], 
        'Username':['Mohamad Askar', 'Noviar Gozali', 'Irene Elysia Gunawan', 'Alvin Oslan', 'Alexander Natanael Sinuraya', 'Devy Martin', 'Cindy Lusiany', 'Francis Anderson', 'Nindya Meranti Iskandar'],
        'Job' : ['Information Technology Industry','Education Industry','Health Industry','Education Industry','Information Technology Industry','Internation Trade and Development Industry','Unemployee','Education Industry','Information Technology Industry']}
df3 = pd.DataFrame(data)

def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')

    mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)

    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in  six.iteritems(mpl_table._cells):
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax

render_mpl_table(df3, header_columns=0, col_width=7.0)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import six
import numpy as np

data = {'No' : ['1','2','3','4','5','6','7','8','9'], 
        'Username':['Mohamad Askar', 'Noviar Gozali', 'Irene Elysia Gunawan', 'Alvin Oslan', 'Alexander Natanael Sinuraya', 'Devy Martin', 'Cindy Lusiany', 'Francis Anderson', 'Nindya Meranti Iskandar'],
        'Angkatan' : [2007,2011,2012,2004,2004,2005,2013,2018,2011]}
df3 = pd.DataFrame(data)

def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')

    mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)

    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in  six.iteritems(mpl_table._cells):
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax

render_mpl_table(df3, header_columns=0, col_width=4.5)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import six
import numpy as np

data = {'No' : ['1','2','3','4','5','6','7','8','9'], 
        'Username':['Mohamad Askar', 'Noviar Gozali', 'Irene Elysia Gunawan', 'Alvin Oslan', 'Alexander Natanael Sinuraya', 'Devy Martin', 'Cindy Lusiany', 'Francis Anderson', 'Nindya Meranti Iskandar'],
        'Program Studi' : ["S1-Manajemen","S1-Sastra Inggris","Profesi-Profesi Dokter","S1-Manajemen","S1-Teknik Elektro","S1-Manajemen","S1-Manajemen","S2-Magister Ilmu Komputer","S1-Desain Interior"]}
df3 = pd.DataFrame(data)

def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')

    mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)

    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in  six.iteritems(mpl_table._cells):
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax

render_mpl_table(df3, header_columns=0, col_width=4.5)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import six
import numpy as np

df3 = pd.read_csv("./output-October.csv")
def render_mpl_table(data, col_width=3.0, row_height=0.625, font_size=14,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')

    mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)

    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in  six.iteritems(mpl_table._cells):
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax

render_mpl_table(df3, header_columns=0, col_width=7)
# Out:
# <AxesSubplot:>
