# %% [markdown]
# # Pertemuan 9
# ## NRP: 2073008
# ## Nama: Evan Julian Sudarman
# ## Version: 15/11/2021

# %% [markdown]
# ### 29. Melakukan random sampling pada sebuah data frame

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.1.3
# 1.19.2

# %%
d = {'col_1':[1, 2, 3, 4, 5], 
     'col_2':[10, 20, 30, 40, 50]}
df = pd.DataFrame(d)
df
# Out:
#    col_1  col_2
# 0      1     10
# 1      2     20
# 2      3     30
# 3      4     40
# 4      5     50

# %%
df.sample(n=4, replace=False, random_state=0) # Membuat sebuah data frame dengan nilai teracak tanpa ada nilai yang redundant.
# Out:
#    col_1  col_2
# 2      3     30
# 0      1     10
# 1      2     20
# 3      4     40

# %%
df.sample(n=4, replace=True, random_state=0) # Membuat sebuah data frame dengan nilai teracak dengan kemungkinan ada nilai yang redundant.
# Out:
#    col_1  col_2
# 4      5     50
# 0      1     10
# 3      4     40
# 3      4     40

# %% [markdown]
# ## 30. Akses nilai variabel pada query()

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#     A   B   C   D   E
# 0   2  15  13  14   6
# 1   6   8  14  13  10
# 2  19   1  11   8  19
# 3   2   1   6  19  11
# 4   3   7  11  12   5

# %%
# Mengakses nilai atau variabel tertentu dengan menggunakan method query.
df.query('A > 10')
# Out:
#     A  B   C   D   E
# 1  12  9  12   2  14
# 2  12  2   2   6   6
# 3  12  5   6  13  14

# %%
# Mencari nilai rata-rata dari kolom A.
rerata = df['A'].mean()
rerata
# Out:
# 8.0

# %%
# Mencari nilai tertentu dengan menggunakan variabel tertentu pada kondisi yang dicantumkan melalui method query, untuk menulis variabel ingin kita jadikan kondisi, kita bisa gunakan keyword @.
df.query('A > @rerata')
# Out:
#     A  B   C   D   E
# 1  12  9  12   2  14
# 2  12  2   2   6   6
# 3  12  5   6  13  14

# %% [markdown]
# ## 31. Tipe data ordinal pada pandas.

# %%
from pandas.api.types import CategoricalDtype
# tipe data ordinal
tingkat_kepuasan = CategoricalDtype(['buruk', 'cukup', 'baik', 'sangat baik'], 
                                    ordered=True)

df['kepuasan'] = df['kepuasan'].astype(tingkat_kepuasan)
df
# Out:
#    pelanggan kepuasan
# 0         11     baik
# 1         12    cukup
# 2         13    buruk
# 3         14    cukup

# %%
df = df.sort_values('kepuasan', ascending=True)
df
# Out:
#    pelanggan kepuasan
# 2         13    buruk
# 1         12    cukup
# 3         14    cukup
# 0         11     baik

# %%
df = df.sort_values('kepuasan', ascending=True)
df
# Out:
#    pelanggan kepuasan
# 2         13    buruk
# 1         12    cukup
# 3         14    cukup
# 0         11     baik

# %%
df[df['kepuasan'] >= 'cukup']
# Out:
#    pelanggan kepuasan
# 1         12    cukup
# 3         14    cukup
# 0         11     baik

# %% [markdown]
# ## 32. Tipe data ordinal pada pandas.

# %%
n_rows = 40
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)
df.head()
# Out:
#     A   B   C   D   E
# 0  13  13  10   3  17
# 1  17   6  16  16  18
# 2  18   1  19  17  10
# 3  12  11  18   8   3
# 4   4  14   3  13  19

# %%
### Persiapan Data Frame
n_rows = 40
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)
df.head()
### Line Plot
df.head()
df.plot(kind='line')
df[['A', 'B']].plot(kind='line')
### Bar Plot
df.head()
df.plot(kind='bar')
df[['A', 'B']].plot(kind='bar')
df[['A', 'B']].head().plot(kind='bar')
df[['A', 'B']].head().plot(kind='barh')
### Area Plot
df.head()
df.plot(kind='area')
df[['A', 'B']].head().plot(kind='area')
### Box Plot
df.head()
df.plot(kind='box')
### Histogram
df.head()
df.plot(kind='hist')
df[['A', 'B']].plot(kind='hist')
### Kernel Density Estimation (KDE)
df.head()
df.plot(kind='kde')
### Scatter Plot
df.head()
df.plot(x='A', y='B', kind='scatter')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>
